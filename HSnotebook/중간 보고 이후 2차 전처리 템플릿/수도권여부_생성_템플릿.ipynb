# %% [markdown]
# # 수도권/비수도권(지방) 여부 컬럼 생성 템플릿

# %%
import pandas as pd

# 파일 불러오기
file_path = [] # 해당 파일 이름
df = pd.read_csv(file_path)

# 수도권 여부 판단 기준
sudogwon = ['서울', '경기', '인천']
df['수도권여부'] = df['지역'].apply(lambda x: '수도권' if x in sudogwon else '비수도권')

# 확인
df[['학교명', '지역', '수도권여부']].head()

# %%
# 수정된 CSV 저장
output_path = "수도권여부_추가완료.csv"
df.to_csv(output_path, index=False, encoding='utf-8-sig')
files.download(output_path)
